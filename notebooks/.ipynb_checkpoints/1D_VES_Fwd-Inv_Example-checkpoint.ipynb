# %%
# This is Matt's adaptation of a pyGimli example notebook, with a few extra details/customizations.

# Check out www.pygimli.org for more examples

# %% [markdown]
# # VES modelling and inversion for a blocky model
#
# This tutorial shows how a built-in forward operator is used for inversion. A DC 1D (VES) model is used to generate data, simulate noise and invert the result, using [pyGIMLi](https://www.pygimli.org).
#
# We can use this type of example/tutorial to consider the limits of VES configurations in various geological contexts. When considering applications of VES in the real world, it's important to consider the ground conditions present. For example, shallow layers of low resistivity can dramatically reduce the effective depth of investigation such that deeper, more resistive layers will be poorly resolved if at all. Furthermore, there are limits to the resolution of thin layers - thin resistive layers in a less resistive volume may be almost invisible, while even thin conductive layers may be detectable, but not properly characterised.

# %% [markdown]
# We first import numpy and pyGIMLi:

# %%
import numpy as np
import pygimli as pg
from pygimli.physics import VESManager

# %% [markdown]
# First, we define some aspects of the survey configuration, starting with 'ab/2' which defines the input (current) electrode spacings, and 'mn/2' as the receiving (voltage) electrodes.
#
# Default example is a log distribution of 40 electrodes from 10^0 (1.0m) to 10^3 (1000m) with mn/2 defined as 1/3 the ab/2 separation.
#
# These can easily be adjusted to test different ranges/densities, or replaced with arrays of values perhaps from a real or planned survey, e.g.
# ```
# ab2 = np.array([1.5, 2.1, 3., 4.2, 6., 9., 13.5, 20., 20., 30., 30., 45., 66.,
#                 100., 150., 150., 220., 220., 330., 500., 750., 1000. ])
# mn2 = np.array([1., 1., 1., 1., 1., 1., 1., 1., 12., 1., 12., 12., 12., 12.,
#                 12., 90., 12., 90., 90., 90., 90., 90 ])
# ```
#
# Both the range and the density of the electrodes can influence the resolution of subsurface layers.

# %%
ab2 = np.logspace(0, 3, 40)  # logspace (a, b, c) creates a list of "c" values from 10^a to 10^b
mn2 = ab2/3
print(f"ab/2 range is {min(ab2):.2f}m to {max(ab2):.2f}m")
# Out:
# ab/2 range is 1.00m to 1000.00m

# %% [markdown]
# Next, define a synthetic model based on n resistivities and n-1 layer thicknesses (the last layer is assumed to be bottomless); when concatenated together, these define the model for the forward operator.

# %%
synres = [50., 5., 50., 500.]  # synthetic resistivity
synthk = [10., 40., 50.]  # synthetic thickness (nlay-th layer is infinite halfspace)
synthModel = synthk + synres  # concatenate thickness and resistivity

# %% [markdown]
# No load the VESManager method from pyGIMLi, and call the simulate function to forward model a simulated dataset for the earth model and survey configuration defined previously.

# %%
ves = VESManager()
rhoa, err = ves.simulate(synthModel, ab2=ab2, mn2=mn2,
                         noiseLevel=0.03, seed=1337)

# %% [markdown]
# Next, still using the VESManager, run layered inversion from the simulated survey data.
#
# It is also possible to include a start model for the invert function, in the same format as the synthetic model created above as a list of thicknesses and resistivities ```[rho1, rho2, rho3, rho4, thk1, thk2, thk3]``` for example:
#
# `startModel=[ 10., 100., 5., 1000., 20., 150., 100. ],`

# %%
ves.invert(data=rhoa, relativeError=err, ab2=ab2, mn2=mn2,
           nLayers=len(synres), lam=1000, lambdaFactor=0.8)
# Out:
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - No data error given, set Fallback set to 1%
# 03/10/24 - 16:34:46 - pyGIMLi - INFO - Created startmodel from forward operator: 7, min/max=0.166667/194.226497
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# 03/10/24 - 16:34:46 - pyGIMLi - WARNING - Multiprocess Jacobian currently unavailable for Win32 and Mac.
# ...

# %% [markdown]
# show estimated & synthetic models and data with model response in 2 subplots

# %%
fig, ax = pg.plt.subplots(ncols=2, figsize=(10, 6))  # two-column figure
ves.showModel(synthModel, ax=ax[0], label="synth", plot="semilogy", zmax=250)
ves.showModel(ves.model, ax=ax[0], label="model", zmax=250)
ves.showData(rhoa, ax=ax[1], label="data", color="C0", marker="x")
out = ves.showData(ves.inv.response, ax=ax[1], label="response", color="C1")
ax[0].set(xlim=(1,10000), ylim=(250,1)) # x is resistivity, y is depth
ax[1].set(xlim=(1,1000), ylim=(1000,1))  # x is resistivity, y is ab/2
# Out:
# [(1, 1000), (1000, 1)]

# %% [markdown]
# This general structure can be used to test and understand the strengths and weaknesses of different VES designs with different ground structures by trying different configurations of ab/2, and different resistivity-depth sets. The original setup works reasonably well (with ```1m =< ab/2 =< 1000m```, and earth model ```[50., 5., 50., 500., 10., 40., 50.]```). The shallow layer, low-resistivity layer and basement are well-resolved, but the intermediate layer above the basement is invisible.
