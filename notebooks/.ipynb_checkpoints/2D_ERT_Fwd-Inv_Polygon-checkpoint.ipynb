# %% [markdown]
# # Forward & Inverse modelling 2D ERT with pyGimli
# ## Fracture/shear zone example
#
# This notebook presents a more complex (for ERT) earth model, with demonstration of the inversion results with different options. With much thanks to the folks behind [pyGimli](https://www.pygimli.org/).
#
# First, load up some packages. We need to have pygimli & numpy in addition to standard python installation, and reference
# the exampledata folder if we want to pick up field data for electrode configurations.

# %%
import pygimli as pg
import numpy as np
from pygimli.physics import ert
import pygimli.meshtools as mt

datafolder = "..\\exampledata\\Lubango\\"

# %% [markdown]
# ## Create the electrode scheme and model
#
# Firstly, create a 'scheme' of electrode locations to integrate into the world mesh later.
#
# The code below shows, firstly, a simulated 21-point dipole-dipole (`dd`) array of electrodes every 5m from `x=0` to `x=100`. Alternately, we can load example data, and load the electrode locations & spacing. Note that the robustness of this option is a little unknown; likely works with any [BERT udf](http://resistivity.net/bert/data_format.html) format files, but might fall down if electrode spacing is variable.
#
# The `maxSeparation` argument is used to limit spread between AB and MN centres (otherwise scheme will include all possible pairs out to the full line length, which is unusual). This limiting can also be achieved later by limiting the geometric factor, `k`, but that is less intuitive.
#
# Other preset configurations include Wenner, `'wa'`, Schlumberger `'slm'` and pole-dipole `'pd'`. To trigger a list, run the
# cell with the `schemeName` set to an unrecognised scheme, e.g. `'abc'`.

# %%
# Option to create 'synthetic' electrode scheme
elecs=np.linspace(start=0, stop=100, num=21)

# Option to use scheme from field data...
#data = ert.load(datafolder + "DD_5-1.ohm") 
#elecs=pg.x(data)

# Create electrode 'scheme'
scheme = ert.createData(elecs=elecs, schemeName='dd', maxSeparation=20)
print(scheme)
# Out:
# Data: Sensors: 21 data: 171, nonzero entries: ['a', 'b', 'k', 'm', 'n', 'valid']

# %% [markdown]
# Next, create a 'world' (with optional layers, bodies, etc) and display it. This currently creates a 'world' with limits based on the `elecs` variable above, with 1 layer at 2 x electrode spacing, and a block below this layer representing (for example) a water-bearing fracture zone.

# %%
spacing = (max(elecs) - min(elecs))/(len(elecs) -1)

world = mt.createWorld(start=[min(elecs)-5*spacing, 0.], 
                       end=[max(elecs)+5*spacing, -10*spacing],
                       layers=[-2*spacing], worldMarker=True)

poly = mt.createPolygon([(9*spacing, -10*spacing), (9*spacing,-2*spacing),
                         (11*spacing,-2*spacing), (11*spacing,-10*spacing)],
                        isClosed=True, addNodes=3, marker=3)

world += poly

pg.show(world);

# %% [markdown]
# It's also possible to define circles, rectangles and polygons with the pygimli meshtools, then add them to the 'world'
# arithmetically, e.g. `world += block`, or to add sloping lines to define dipping interfaces. More details of arguments at [pygimli.meshtools](https://www.pygimli.org/pygimliapi/_generated/pygimli.meshtools.html#module-pygimli.meshtools) and some examples of adding lines to a 'world' later in this notebook.
#
# Some examples:
# ```
# ball = mt.createCircle(pos=[25, -3.], radius=[4, 1], marker=4, boundaryMarker=10, area=0.1)
#
# poly = mt.createPolygon([(11,-4), (12,-1.5), (14,-2), (15,-2), (18,-3), (15,-3.5), (13,-4.5)], isClosed=True, addNodes=3, interpolate='spline', marker=5)
#
# block = mt.createRectangle(start = [55,-4], end = [60,-10], marker=6)
# ```

# %% [markdown]
# ## Create mesh for earth model & electrode locations
#
# Next, create the mesh within the 'world' for the earth model. The electrode scheme defines nodes in the mesh (with additional
# nodes at 1/10 spacing on recommendations from pyGimli devs). We then define a resistivity mapping for the layers and block, and
# display the model.

# %%
for p in scheme.sensors():
    world.createNode(p)
    world.createNode(p - [0, 0.1])

mesh = mt.createMesh(world, quality=34)

rhomap = [[0,150.],[1,50.],[2,150.],[3,10.]]

ax, _ = pg.show(mesh, data=rhomap, label=pg.unit('resistivity Ohm.m'),
                showMesh=True, cMap="Spectral_r")
ax.set_ylim(-10*spacing,0);

# %% [markdown]
# ## Run the forward model & display result

# %%
fwddata = ert.simulate(mesh, scheme=scheme, res=rhomap, noiseLevel=1,
                    noiseAbs=1e-6, seed=1337);

# set information fields
pg.info(np.linalg.norm(fwddata['err']), np.linalg.norm(fwddata['rhoa']))
pg.info('Simulated data', fwddata)
pg.info('The data contains:', fwddata.dataMap().keys())

pg.info('Simulated rhoa (min/max)', min(fwddata['rhoa']), max(fwddata['rhoa']))
pg.info('Selected data noise %(min/max)', min(fwddata['err'])*100, max(fwddata['err'])*100)

ert.show(fwddata);
# Out:
# 15/10/24 - 10:54:23 - pyGIMLi - INFO - Data error estimate (min:max)  0.010001889163482118 : 0.011379558289461288
# 15/10/24 - 10:54:23 - pyGIMLi - INFO - 0.13392683853366577 744.6606684155417
# 15/10/24 - 10:54:23 - pyGIMLi - INFO - Simulated data Data: Sensors: 21 data: 171, nonzero entries: ['a', 'b', 'err', 'k', 'm', 'n', 'rhoa', 'valid']
# 15/10/24 - 10:54:23 - pyGIMLi - INFO - The data contains: ['a', 'b', 'err', 'i', 'ip', 'iperr', 'k', 'm', 'n', 'r', 'rhoa', 'u', 'valid']
# 15/10/24 - 10:54:23 - pyGIMLi - INFO - Simulated rhoa (min/max) 38.28743572364924 84.74559088227099
# 15/10/24 - 10:54:23 - pyGIMLi - INFO - Selected data noise %(min/max) 1.0001889163482118 1.137955828946129
# relativeError set to a value > 0.5 .. assuming this is a percentage Error level dividing them by 100

# %% [markdown]
# Show geometric factors, for reference/information value. Can be useful for limiting maximum AB-MN separation if this is not done with `maxSeparation` earlier in producing the electrode scheme.

# %%
print(fwddata['k'])
#fwddata.remove(-fwddata['k'] > 400000)
ert.show(fwddata, -fwddata['k'], logScale=True)
# Out:
# 171 [-94.24777960769379,...,-107442.46875276748]
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x26807af1f90>)

# %% [markdown]
# ## Run inversion of forward modelled output
#
# First inversion test is completely open with automated mesh definition, and no constraints. With this earth model, it may be worthwhile to emphasis layering by adjusting the `zWeight`. We'll try that option following...

# %%
mgr = ert.ERTManager(fwddata);

inv = mgr.invert(lam=20, verbose=True, zWeight=1, quality=34, size=1.);
# np.testing.assert_approx_equal(mgr.inv.chi2(), 0.7, significant=1) # Not sure what this does, taken from pyGimli example

# plot inversion result with input/output pseudosections
mgr.showResultAndFit();

# plot just inversion result with fixed axis limits
# ax, _ = mgr.showResult(xlabel="x (m)", ylabel="z (m)", cMap="Spectral_r")
# ax.set_xlim(-10,110)
# Out:
# 15/10/24 - 10:55:13 - pyGIMLi - INFO - Found 2 regions.
# 15/10/24 - 10:55:13 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Found 2 regions.
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1529 Cells: 2904 Boundaries: 2254
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Use median(data values)=54.146605967110155
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Created startmodel from forward operator: 404, min/max=54.146606/54.146606
# 15/10/24 - 10:55:14 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002680F600EA0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x000002680B30A3E0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002680F6360C0>
# min/max (data): 38.29/84.75
# min/max (error): 1%/1.14%
# min/max (start model): 54.15/54.15
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  291.61
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   45.07 (dPhi = 84.15%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    7.79 (dPhi = 80.04%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    0.89 (dPhi = 74.11%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.89)                   #
# ################################################################################

# %% [markdown]
# Now, a very similar unconstrained inversion but using a low value of `zWeight` that allows for better characterising the layered earth model.

# %%
#mgr = ert.ERTManager(fwddata);

invLowz = mgr.invert(lam=20, verbose=True, zWeight=0.1, quality=34, size=1.);
# np.testing.assert_approx_equal(mgr.inv.chi2(), 0.7, significant=1) # Not sure what this does, taken from pyGimli example

# plot inversion result with input/output pseudosections
mgr.showResultAndFit();

# plot just inversion result with fixed axis limits
# ax, _ = mgr.showResult(xlabel="x (m)", ylabel="z (m)", cMap="Spectral_r")
# ax.set_xlim(-10,110)
# Out:
# 15/10/24 - 10:55:27 - pyGIMLi - INFO - Use median(data values)=54.146605967110155
# 15/10/24 - 10:55:27 - pyGIMLi - INFO - Created startmodel from forward operator: 404, min/max=54.146606/54.146606
# 15/10/24 - 10:55:27 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000002680F600EA0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x000002680B30A3E0>
# Model transformation (cumulative):
# 	 0 <pgcore._pygimli_.RTransLogLU object at 0x000002680F57A500>
# min/max (data): 38.29/84.75
# min/max (error): 1%/1.14%
# min/max (start model): 54.15/54.15
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  291.61
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   87.84 (dPhi = 69.83%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   21.86 (dPhi = 74.87%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    0.77 (dPhi = 95.31%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.77)                   #
# ################################################################################

# %% [markdown]
# ## Inversion with layer boundaries
#
# If we have confidence on the depth of layer interfaces, we can include them in the definition of a mesh for the inversion,
# with dramatic results.
#
# Create a similar 'world' with a horizontal line for the overburden boundary:

# %%
geo = world = mt.createParaMeshPLC(fwddata, paraDepth=10*spacing, boundary=1)
                     #mt.createWorld(start=[min(elecs)-5*spacing, 0.], 
                     #end=[max(elecs)+5*spacing, -10*spacing],
                     #worldMarker=True)

line1 = pg.meshtools.createLine(start=[min(elecs)-1*spacing, -2*spacing],
                                end=[max(elecs)+1*spacing, -2*spacing],
                                marker=2) # marker>0 means it functions as a constraint
#line2 = pg.meshtools.createLine(start=[min(elecs)-4*spacing, -3.5*spacing],
#                                end=[max(elecs)+4*spacing, -3.5*spacing],
#                                marker=3) # marker>0 means it functions as a constraint

geo += line1 #+ line2

pg.show(geo)

for p in scheme.sensors():
    geo.createNode(p)
    geo.createNode(p - [0, 0.1])

invmesh = pg.meshtools.createMesh(geo, quality=34)
ax, _ = pg.show(invmesh)
#ax.set_xlim(min(elecs)-5*spacing, max(elecs)+5*spacing);
#ax.set_ylim(-10*spacing, 0);

# %% [markdown]
# Now re-run the inversion and display...

# %%
mgrLayered = ert.ERTManager(fwddata)
layeredinv = mgrLayered.invert(verbose=True, lam=20, mesh=invmesh)

mgrLayered.showResultAndFit();
# Out:
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Found 2 regions.
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 6755 Cells: 12760 Boundaries: 9944
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Use median(data values)=54.146605967110155
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Created startmodel from forward operator: 2872, min/max=54.146606/54.146606
# 15/10/24 - 10:56:15 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x0000026813A62D90>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x0000026813A7B6A0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x0000026813A7A520>
# min/max (data): 38.29/84.75
# min/max (error): 1%/1.14%
# min/max (start model): 54.15/54.15
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  291.61
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =   52.52 (dPhi = 81.70%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   19.96 (dPhi = 60.87%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    2.00 (dPhi = 85.94%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    0.66 (dPhi = 45.39%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.66)                   #
# ################################################################################

# %% [markdown]
# From these results, or other data, maybe we could estimate the extent of the basement anomaly and add lines to more sharply constrain that part of the inversion:

# %%
vline1 = pg.meshtools.createLine(start=[9*spacing, -2*spacing],
                                end=[9*spacing, -8*spacing], marker = 3)
vline2 = pg.meshtools.createLine(start=[11*spacing, -2*spacing],
                                end=[11*spacing, -8*spacing], marker = 4)

geoblock = geo + vline1 + vline2

pg.show(geoblock)

for p in scheme.sensors():
    geo.createNode(p)
    geo.createNode(p - [0, 0.1])

blockmesh = pg.meshtools.createMesh(geoblock, quality=34)
ax, _ = pg.show(blockmesh)

# %% [markdown]
# And run another inversion with this further constraint...

# %%
mgrBlock = ert.ERTManager(fwddata)
blockinv = mgrBlock.invert(verbose=True, lam=20, mesh=blockmesh)

mgrBlock.showResultAndFit();
# Out:
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Found 2 regions.
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 6737 Cells: 12728 Boundaries: 9918
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Use median(data values)=54.146605967110155
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Created startmodel from forward operator: 2816, min/max=54.146606/54.146606
# 15/10/24 - 10:57:20 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000268115EA570>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x000002680B59FFB0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x00000268108EF380>
# min/max (data): 38.29/84.75
# min/max (error): 1%/1.14%
# min/max (start model): 54.15/54.15
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  291.61
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =  115.66 (dPhi = 60.28%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   73.93 (dPhi = 36.02%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   52.09 (dPhi = 29.41%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    9.31 (dPhi = 81.74%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =    1.94 (dPhi = 76.93%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =    0.76 (dPhi = 53.18%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.76)                   #
# ################################################################################

# %% [markdown]
# Finally, we can display the results from these different options for the inversion, with the original 'world' first for comparison.

# %%
kwargs = {'xlabel':"x (m)", 'ylabel':"z (m)", 'cMap':"Spectral_r", 'cMin':10, 'cMax':150, 'logScale':False}

ax, _ = pg.show(mesh, data=rhomap, showMesh=False, label="Model Resistivity ohm.m", **kwargs)
ax.set_xlim(min(elecs)-5*spacing, max(elecs)+5*spacing);
ax.set_ylim(-10*spacing, 0);

ax, _ = mgr.showResult(inv, label="Inversion resistivity ohm.m (zWeight=1)",**kwargs)
ax.set_xlim(min(elecs)-5*spacing, max(elecs)+5*spacing);
ax.set_ylim(-10*spacing, 0);

ax, _ = mgr.showResult(invLowz, label="Inversion resistivity ohm.m (zWeight=0.1)",**kwargs)
ax.set_xlim(min(elecs)-5*spacing, max(elecs)+5*spacing);
ax.set_ylim(-10*spacing, 0);

ax, _ = mgrLayered.showResult(layeredinv, label="Inversion resistivity ohm.m",**kwargs)
ax.set_xlim(min(elecs)-5*spacing, max(elecs)+5*spacing);
ax.set_ylim(-10*spacing, 0);

ax, _ = mgrBlock.showResult(blockinv, label="Inversion resistivity ohm.m",**kwargs)
ax.set_xlim(min(elecs)-5*spacing, max(elecs)+5*spacing);
ax.set_ylim(-10*spacing, 0);

# %% [markdown]
# If of interest, the user can also try out different configurations and/or earth models. The result and success (or otherwise) of the survey is a complex balance between the configuration and scale of the survey configuration, and the dimension and resistivity of the subsurface units.
